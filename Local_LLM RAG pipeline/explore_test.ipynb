# %%
from vllm import LLM, SamplingParams
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from typing import List, Optional,Tuple
import pandas as pd

# %%
train_data = pd.read_json("../qa/wikipedia-train.json")
validation_data = train_data.iloc[:7900]

# %%
# Define the model
READER_MODEL_NAME = "AMead10/Llama-3.2-3B-Instruct-AWQ"
#READER_MODEL_NAME = "neuralmagic/Llama-3.2-3B-Instruct-quantized.w8a8"
# Configure the model
model = LLM( 
    model = READER_MODEL_NAME,
    #quantization="awq",
    tensor_parallel_size=1, 
    gpu_memory_utilization=1.0, 
    trust_remote_code=True,
    enforce_eager=True,
    disable_log_stats=True,
    max_model_len=4096
)
# Out:
# INFO 04-06 21:53:58 [config.py:585] This model supports multiple tasks: {'classify', 'reward', 'score', 'generate', 'embed'}. Defaulting to 'generate'.
# INFO 04-06 21:53:58 [config.py:1697] Chunked prefill is enabled with max_num_batched_tokens=8192.
# WARNING 04-06 21:53:58 [cuda.py:95] To see benefits of async output processing, enable CUDA graph. Since, enforce-eager is enabled, async output processor cannot be used
# WARNING 04-06 21:53:59 [utils.py:2181] We must use the `spawn` multiprocessing start method. Overriding VLLM_WORKER_MULTIPROC_METHOD to 'spawn'. See https://docs.vllm.ai/en/latest/getting_started/troubleshooting.html#python-multiprocessing for more information. Reason: CUDA is initialized
# INFO 04-06 21:54:03 [__init__.py:239] Automatically detected platform cuda.
# INFO 04-06 21:54:04 [core.py:54] Initializing a V1 LLM engine (v0.8.2) with config: model='neuralmagic/Llama-3.2-3B-Instruct-quantized.w8a8', speculative_config=None, tokenizer='neuralmagic/Llama-3.2-3B-Instruct-quantized.w8a8', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.bfloat16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=compressed-tensors, enforce_eager=True, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar', reasoning_backend=None), observability_config=ObservabilityConfig(show_hidden_metrics=False, otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=None, served_model_name=neuralmagic/Llama-3.2-3B-Instruct-quantized.w8a8, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=False, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[],"max_capture_size":0}
# WARNING 04-06 21:54:04 [utils.py:2321] Methods determine_num_available_blocks,device_config,get_cache_block_size_bytes,initialize_cache not implemented in <vllm.v1.worker.gpu_worker.Worker object at 0x7f60bd6d7f50>
# INFO 04-06 21:54:05 [parallel_state.py:954] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0
# WARNING 04-06 21:54:05 [interface.py:303] Using 'pin_memory=False' as WSL is detected. This may slow down the performance.
# INFO 04-06 21:54:05 [cuda.py:220] Using Flash Attention backend on V1 engine.
# INFO 04-06 21:54:05 [gpu_model_runner.py:1174] Starting to load model neuralmagic/Llama-3.2-3B-Instruct-quantized.w8a8...
# INFO 04-06 21:54:05 [compressed_tensors_w8a8_int8.py:51] Using CutlassScaledMMLinearKernel for CompressedTensorsW8A8Int8
# WARNING 04-06 21:54:07 [topk_topp_sampler.py:63] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# INFO 04-06 21:54:07 [weight_utils.py:265] Using model weights format ['*.safetensors']
# INFO 04-06 21:54:07 [weight_utils.py:315] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:04<00:00,  4.12s/it]
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:04<00:00,  4.12s/it]
# INFO 04-06 21:54:11 [loader.py:447] Loading weights took 4.38 seconds
# INFO 04-06 21:54:12 [gpu_model_runner.py:1186] Model loading took 3.4213 GB and 6.436726 seconds
# INFO 04-06 21:54:18 [kv_cache_utils.py:566] GPU KV cache size: 5,760 tokens
# INFO 04-06 21:54:18 [kv_cache_utils.py:569] Maximum concurrency for 4,096 tokens per request: 1.41x
# INFO 04-06 21:54:19 [core.py:151] init engine (profile, create kv cache, warmup model) took 7.00 seconds

# %%
# Load the components of the RAG system

tokenizer = model.get_tokenizer()

prompt_in_chat_format = [
    {
        "role": "system",
        "content": """Answer the question with only one word or the simplest possible response (e.g., a single number or a single word).
Do NOT generate sentences, explanations, or additional context.
Stop immediately after providing the answer. Do not generate any further words or tokens.
If the context does not provide any useful information, answer the question based on your own knowledge.
I am going to provide you five examples:

Question: What is the capital of Kenya?
Answer: Nairobi
---
Question: What was the name of the pig leader in George Orwell's Animal Farm?
Answer: Napoleon
---
Question: Which artist created the Katzenjammer Kids?
Answer: Rudolph Dirks
---
Question: Who was Geena Davis's husband when they made the loss-maker Cutthroat Island?
Answer: Renny Harlin
---
Question: Who was married to Spandau Ballet's Gary Kemp and later to Jude Law?
Answer: Sadie Frost

"""
    },
    {
        "role": "user",
        "content": """Context:
{context}
---
Now here is the question you need to answer.

Question: {question}"""
    },
]

RAG_PROMPT_TEMPLATE = tokenizer.apply_chat_template(
    prompt_in_chat_format, tokenize=False, add_generation_prompt=True
)

sampling_params = SamplingParams(
    n = 1,
    top_p=0.9,
    temperature=0,
    repetition_penalty=1.2,
    max_tokens=10,     
)

# The name of the embedding model
EMBEDDING_MODEL_NAME = "thenlper/gte-small"
# HuggingFace Embedding Model
embedding_model = HuggingFaceEmbeddings(
    model_name=EMBEDDING_MODEL_NAME,
    multi_process=True,
    model_kwargs={"device": "cuda"},
    encode_kwargs={"normalize_embeddings": True},  # Set `True` for cosine similarity
)

faiss_index_path = "knowledge_vector_database-validation"
KNOWLEDGE_VECTOR_DATABASE = FAISS.load_local(faiss_index_path, embedding_model, allow_dangerous_deserialization=True)

# def retrieve(
#     question: str,
#     embedding: List[float],
#     knowledge_index,
#     num_docs_final: int = 3,
#     printing: bool = True,
# ) -> Tuple[str, List[str]]:
#     """
#     Retrieves documents from the FAISS knowledge index.
#     """
#     if printing:
#         print("=> Retrieving documents...")

#     # Perform search using the precomputed embedding
#     relevant_docs = knowledge_index.similarity_search_by_vector(embedding, k=num_docs_final)
#     relevant_docs = [doc.page_content for doc in relevant_docs]  # Extract only the content

#     # Build the context for the LLM model
#     context = "\nExtracted documents:\n" + "".join(
#         [f"Document {i}:::\n{doc}\n" for i, doc in enumerate(relevant_docs)]
#     )

#     return context, relevant_docs
def retrieve(
    question: str,
    embedding: List[float],
    knowledge_index,
    num_docs_final: int = 3,
    printing: bool = True,
) -> Tuple[str, List[str]]:
    """
    Retrieves documents from the FAISS knowledge index.
    """
    if printing:
        print("\n" + "="*50)
        print(f"=> Retrieving documents for question:\n{question}\n")

    # Perform search using the precomputed embedding
    relevant_docs = knowledge_index.similarity_search_by_vector(embedding, k=num_docs_final)
    relevant_docs = [doc.page_content for doc in relevant_docs]  # Extract only the content

    if printing:
        print(f"=> Retrieved {len(relevant_docs)} documents:")
        for i, doc in enumerate(relevant_docs):
            preview = doc[:200].replace("\n", " ") + ("..." if len(doc) > 200 else "")
            print(f"Document {i + 1}: {preview}")

    # Build the context for the LLM model
    context = "\nExtracted documents:\n" + "".join(
        [f"Document {i}:::\n{doc}\n" for i, doc in enumerate(relevant_docs)]
    )

    return context, relevant_docs

def read(llm, sampling_params, prompt_template, contexts, questions):
    """
    Generates answers from the LLM by formatting the question-context pairs into prompts.
    """
    # Format prompts by combining questions and contexts
    prompts = [prompt_template.format(question=q, context=c) for q, c in zip(questions, contexts)]
    
    # Generate answers using the LLM
    outputs = llm.generate(prompts, sampling_params)
    
    # Extract the generated text from the outputs
    outputs = [output.outputs[0].text for output in outputs]
    
    return outputs

# Main function to answer questions using RAG
def answer_with_rag(
    questions: List[str],
    llm,
    prompt_template,
    sampling_params: dict,
    knowledge_index,
    embedding_model,
    num_docs_final: int = 3,
    printing: bool = True,
) -> List[str]:
    """
    Main function for answering questions using a Retrieval-Augmented Generation (RAG) pipeline.
    """
    # Ensure that questions are in list format
    if isinstance(questions, str):
        questions = [questions]

    # Calculate all embeddings for the questions at once
    embeddings = embedding_model.embed_documents(questions)

    # Retrieve contexts for each question
    contexts = []
    relevant_docs_list = []
    
    for idx, question in enumerate(questions):
        # Use the precomputed embedding for each question
        embedding = embeddings[idx]
        context, relevant_docs = retrieve(
            question,
            embedding=embedding,
            knowledge_index=knowledge_index,
            num_docs_final=num_docs_final,
            printing=printing,
        )
        contexts.append(context)
        relevant_docs_list.append(relevant_docs)

    # Generate answers using the LLM model
    if printing:
        print("=> Generating answers...")
    answers = read(llm, sampling_params, prompt_template, contexts, questions)

    return answers, relevant_docs_list

# %%
question = "Where was born the Queen Elizabeth II?"

answers, relevant_docs_list = answer_with_rag(
    questions=question,
    llm=model,
    prompt_template=RAG_PROMPT_TEMPLATE,
    sampling_params=sampling_params,
    knowledge_index=KNOWLEDGE_VECTOR_DATABASE, 
    embedding_model=embedding_model,
    num_docs_final=3,
    printing=True
)

print("Question: ", question)
print("Answer: ", answers[0])
print("Relevant Docs: ", relevant_docs_list[0])
# Out:
# => Retrieving documents...
# => Generating answers...
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.83it/s, est. speed input: 2453.44 toks/s, output: 5.50 toks/s]
# Question:  Where was born the Queen Elizabeth II?
# Answer:  Greenwich
# Relevant Docs:  ["Elizabeth II (Elizabeth Alexandra Mary; born 21 April 1926) is, and has been since her accession in 1952, Queen of the United Kingdom, Canada, Australia, and New Zealand, and Head of the Commonwealth. She is also Queen of 12 countries that have become independent since her accession: Jamaica, Barbados, the Bahamas, Grenada, Papua New Guinea, Solomon Islands, Tuvalu, Saint Lucia, Saint Vincent and the Grenadines, Belize, Antigua and Barbuda, and Saint Kitts and Nevis.\n\nElizabeth was born in London to the Duke and Duchess of York, later King George VI and Queen Elizabeth, and was the elder of their two daughters. She was educated privately at home. Her father acceded to the throne on the abdication of his brother Edward VIII in 1936, from which time she was the heir presumptive. She began to undertake public duties during the Second World War, serving in the Auxiliary Territorial Service. In 1947, she married Prince Philip, Duke of Edinburgh, with whom she has four children: Charles, Anne, Andrew, and Edward.\n\nElizabeth's many historic visits and meetings include a state visit to the Republic of Ireland and reciprocal visits to and from the Pope. She has seen major constitutional changes, such as devolution in the United Kingdom, Canadian patriation, and the decolonisation of Africa. She has also reigned through various wars and conflicts involving many of her realms. She is the world's oldest reigning monarch as well as Britain's longest-lived. In 2015, she surpassed the reign of her great-great-grandmother, Queen Victoria, to become the longest-reigning British monarch and the longest-reigning queen regnant and female head of state in world history.", "Early life \n\nElizabeth was born at Greenwich Palace and was named after both her grandmothers, Elizabeth of York and Elizabeth Howard.  She was the second child of Henry VIII of England born in wedlock to survive infancy. Her mother was Henry's second wife, Anne Boleyn. At birth, Elizabeth was the heiress presumptive to the throne of England. Her older half-sister, Mary, had lost her position as a legitimate heir when Henry annulled his marriage to Mary's mother, Catherine of Aragon, to marry Anne, with the intent to sire a male heir and ensure the Tudor succession.   Elizabeth was baptised on 10 September; Archbishop Thomas Cranmer, the Marquess of Exeter, the Duchess of Norfolk and the Dowager Marchioness of Dorset stood as her godparents.\n\nWhen Elizabeth was two years and eight months old, her mother was executed on 19 May 1536.  Elizabeth was declared illegitimate and deprived of her place in the royal succession.  Eleven days after Anne Boleyn's death, Henry married Jane Seymour, but she died shortly after the birth of their son, Prince Edward, in 1537. From his birth, Edward was undisputed heir apparent to the throne. Elizabeth was placed in his household and carried the chrisom, or baptismal cloth, at his christening.", 'Elizabeth\'s only sibling, Princess Margaret, was born in 1930. The two princesses were educated at home under the supervision of their mother and their governess, Marion Crawford, who was casually known as "Crawfie".  Lessons concentrated on history, language, literature and music.  Crawford published a biography of Elizabeth and Margaret\'s childhood years entitled The Little Princesses in 1950, much to the dismay of the royal family.  The book describes Elizabeth\'s love of horses and dogs, her orderliness, and her attitude of responsibility.  Others echoed such observations: Winston Churchill described Elizabeth when she was two as "a character. She has an air of authority and reflectiveness astonishing in an infant."  Her cousin Margaret Rhodes described her as "a jolly little girl, but fundamentally sensible and well-behaved". \n\nHeir presumptive\n\nDuring her grandfather\'s reign, Elizabeth was third in the line of succession to the throne, behind her uncle Edward, Prince of Wales, and her father, the Duke of York. Althou ...

# %%
validation_data_batch = validation_data[0:500]
questions = [instance["Question"] for instance in validation_data_batch["Data"]]
answers, _ = answer_with_rag(
    questions=questions,
    llm=model,
    prompt_template=RAG_PROMPT_TEMPLATE,
    sampling_params=sampling_params,
    knowledge_index=KNOWLEDGE_VECTOR_DATABASE,
    embedding_model=embedding_model,
    num_docs_final=5,
    printing=False
)
for q, a in zip(questions, answers):
    print("Question: ", q)
    print("Answer: ", a)
# Out:
# Processed prompts: 100%|██████████| 500/500 [04:48<00:00,  1.73it/s, est. speed input: 4161.80 toks/s, output: 5.92 toks/s]
# Question:  Where in England was Dame Judi Dench born?
# Answer:  Heworth
# Question:  From which country did Angola achieve independence in 1975?
# Answer:  Portugal
# Question:  Which city does David Soul come from?
# Answer:  Chicago
# Question:  Who won Super Bowl XX?
# Answer:  Bears
# Question:  Which was the first European country to abolish capital punishment?
# Answer:  Italy
# Question:  In which country did he widespread use of ISDN begin in 1988?
# Answer:  Japan
# Question:  What is Bruce Willis' real first name?
# Answer:  Bruce
# Question:  Which William wrote the novel Lord Of The Flies?
# Answer:  Golding
# Question:  How is Joan Molinsky better known?
# Answer:  Joan
# Question:  In which branch of the arts is Patricia Neary famous?
# Answer:  Dance
# Question:  Which country is Europe's largest silk producer?
# Answer:  No data provided
# Question:  The VS-300 was a type of what?
# Answer:  Helicopter
# Question:  At which university did Joseph Goebbels become a doctor of philosophy?
# Answer:  University of Heidelberg
# Question:  Which prince is Queen Elizabeth II's youngest son?
# Answer:  Prince Andrew
# Question:  When did the founder of Jehovah's Witnesses say the world would end?
# Answer:  Never
# Question:  Who was the only Spice Girl not to have a middle name?
# Answer:  Victoria
# Question:  What are the international registration letters of a vehicle from Algeria?
# Answer:  BA
# Question:  How did Jock die in Dallas?
# Answer:  Helicopter crash
# Question:  Who wrote the novel Evening Class?
# Answer:  Maeve Binchy
# Question:  Which country does the airline Air Pacific come from?
# Answer:  Australia
# Question:  In which branch of the arts does Allegra Kent work?
# Answer:  Dance
# Question:  Who had a 70s No 1 hit with Billy, Don't Be A Hero?
# Answer:  Bo Donaldson
# Question:  Who directed the movie La Dolce Vita?
# Answer:  Federico Fellini
# Question:  Which country does the airline LACSA come from?
# Answer:  El Salvador
# Question:  Who directed 2001: A Space Odyssey?
# Answer:  Stanley Kubrick
# Question:  Which is the largest of the Japanese Volcano Islands?
# Answer:  Honshu
# Question:  Ezzard Charles was a world champion in which sport?
# Answer:  Boxing
# Question:  Who was the first woman to make a solo flight across the Atlantic?
# Answer:  Amelia Earhart
# Question:  Which port lies between Puget Sound and Lake Washington?
# Answer:  Seattle
# Question:  Who became US Vice President when Spiro Agnew resigned?
# Answer:  Gerald Ford
# Question:  Which George invented the Kodak roll-film camera?
# Answer:  George Eastman
# Question:  Which series had the characters Felix Unger and Oscar Madison?
# Answer:  TV
# Question:  Who along with Philips developed the CD in the late 70s?
# Answer:  Sony
# Question:  Where is the multinational Nestle based?
# Answer:  Vevey
# Question:  19969 was the Chinese year of which creature?
# Answer:  Rat
# Question:  In the 90s how many points have been awarded for finishing second in a Grand Prix?
# Answer:  6
# Question:  Stapleton international airport is in which US state?
# Answer:  Colorado
# Question:  What was Kevin Kline's first movie?
# Answer:  Sophie's Choice
# Question:  What day of the week was the Wall Street Crash?
# Answer:  Thursday
# Question:  The US signed a treaty with which country to allow the construction of the Panama Canal?
# Answer:  Panama
# Question:  What was Prince's last No 1 of the 80s?
# Answer:  "When Doves Cry"
# Question:  Man In The Mirror first featured on which Michel Jackson album?
# Answer:  Bad
# Question:  Where was the first battle with US involvement in the Korean War?
# Answer:  Osan
# Question:  On which Caribbean island did Princess Diana spend he first Christmas after her divorce was announced?
# Answer:  Barbados
# Question:  In which decade was Arnold Schwarzenegger born?
# Answer:  1940s
# Question:  Which musical featured the song Thank Heaven for Little Girls?
# Answer:  Gigi
# Question:  The Queen Elizabeth liner was destroyed by fire in the 70s in which harbour?
# Answer:  Port Rashid
# Question:  What breed of dog did Columbo own?
# Answer:  None
# Question:  Phil Collins appeared in which Spielberg film with Robin Williams?
# Answer:  Hook
# Question:  1998 was the Chinese year of which creature?
# Answer:  Dragon
# Question:  Which country does musician Alfred Brendel come from?
# Answer:  Czechoslovakia
# Question:  Theodore Francis international airport is in which US state?
# Answer:  California
# Question:  In which soap did Demi Moore find fame?
# Answer:  General Hospital
# Question:  To the nearest million, what is the population of London, England?
# Answer:  54
# Question:  What did Clarice Cliff create?
# Answer:  Ceramics
# Question:  Which James Bond film features a song by Louis Armstrong?
# Answer:  Dr. No
# Question:  In what year were US ground troops first dispatched to Vietnam?
# Answer:  1965
# Question:  In 1999 Anna Kournikova signed a lucrative contract to model what?
# Answer:  Berlei
# Question:  Which member of the Monkees came from Washington DC?
# Answer:  None
# Question:  Who had the noels Spy Hook and Spy Line published in the 80s?
# Answer:  Len Deighton
# Question:  In which country was Ursula Andrews born?
# Answer:  India
# Question:  What was CBS TV news broadcaster Walter Cronkite's stock closing phrase?
# Answer:  "It seems like a good idea..."
# Question:  Who had a 70s No 1 hit with Let Your Love Flow?
# Answer:  Bellamy Brothers
# Question:  Which state renewed Mike Tyson's boxing license in 1998?
# Answer:  Arizona
# Question:  Neil Armstrong was a pilot in which war?
# Answer:  Korean
# Question:  Nickelodeon was founded in 1979 by which company?
# Answer:  Warner Communications
# Question:  Which element along with polonium did the Curies discover?
# Answer:  Radium
# Question:  In The Banana Splits what sort of animal was Snorky?
# Answer:  Elephant
# Question:  Who had an 80s No 1 hit with Can't Fight This Feeling?
# Answer:  REO Speedwagon
# Question:  Which parallel was the truce line in the Korean War?
# Answer:  38th
# Question:  On a computer keyboard which letter is between A and D?
# Answer:  D
# Question:  What was Hitchcock's first sound movie?
# Answer:  Blackmail
# Question:  Which newspaper did Jackie Kennedy work for just before her marriage?
# Answer:  Washington Times-Herald
# Question:  What are the international registration letters of a vehicle from Turkey?
# Answer:  XX
# Question:  Who wrote The Turn Of The Screw in the 19th century and The Ambassadors in the 20th?
# Answer:  Henry James
# Question:  Which American nuclear submarine was the first to sail across the North Pole under the ice cap?
# Answer:  Nautilus
# Question:  What was John Glenn/'s first spacecraft called?
# Answer:  Friendship 7
# Question:  Which branch of medicine is concerned with disorders of the blood?
# Answer:  Hematology
# Question:  Where was The Iron Triangle?
# Answer:  Vietnam
# Question:  What is the correct name of laughing gas?
# Answer:  Nitrous
# Question:  What is the distance between bases on a little league baseball field?
# Answer:  Not provided
# Question:  How many home runs did baseball great Ty Cobb hit in the three world series in which he played?
# Answer:  None
# Question:  "What breakfast food gets its name from the German word for ""stirrup""?"
# Answer:  Pumpernickel
# Question:  What American city produces most of the egg rolls sold in grocery stores in the United States?
# Answer:  None
# Question:  Which 100-mile long waterway links the Mediterranean and the Red Sea?
# Answer:  Suez Canal
# Question:  In which country is the Aswan Dam?
# Answer:  Egypt
# Question:  Where did Idi Amin rule from 1971-1979?
# Answer:  Uganda
# Question:  Which country has the rand as its currency?
# Answer:  South Africa
# Question:  What is the former name of the People's Republic of Venin?
# Answer:  None
# Question:  In which country are Tangier and Casablanca?
# Answer:  Morocco
# Question:  Who was the Egyptian president who was assassinated in 1981?
# Answer:  Anwar
# Question:  Which country was called Upper Volta until 1984?
# Answer:  Burkina Faso
# Question:  Who was the Egyptian king whose tomb an treasures were discovered in the Valley of the Kings in 1922?
# Answer:  Tutankhamun
# Question:  What are the two main arms of the River Nile called?
# Answer:  White Nile
# Blue Nile
# Question:  In which country did King Hassan II ascend the throne in 1961?
# Answer:  Morocco
# Question:  Which British general was killed at Khartoum in 1885?
# Answer:  Charles George Gordon
# Question:  On the border of which two countries is Victoria Falls?
# Answer:  Zambia
# Zimbabwe
# Question:  What is the name of the volcanic valley that runs from the Sinai peninsula to central Mozambique?
# Answer:  Great Rift Valley
# Question:  Which actor won an Academy Award for his performance in The African Queen?
# Answer:  Humphrey Bogart
# Question:  Who wrote the novel Cry, the Beloved Country about South Africa?
# Answer:  Alan
# Question:  What is the capital of Kenya?
# Answer:  Nairobi
# Question:  From which European country did Angola achieve independence in 1975?
# Answer:  Portugal
# Question:  Which country mainly makes up the Horn of Africa?
# Answer:  None
# Question:  What is the capital of Sierra Leone?
# Answer:  Freetown
# Question:  Which country is the island of Zanzibar part of?
# Answer:  Tanzania
# Question:  What is Africa's largest country?
# Answer:  Algeria
# Question:  Which African country is bordered by Benin, Ghana, Ivory Coast, Niger, and Mali?
# Answer:  Niger
# Question:  Who was the woman sentenced to six years in jail after the murder of Stompei Seipi?
# Answer:  None
# Question:  In which country are the towns of Gweru and Kwekwe?
# Answer:  Zimbabwe
# Question:  Who was the founder of the Back to Africa movement who largely inspired Rastafarianism?
# Answer:  Marcus
# Question:  Which African country is sandwiched between Ghana and Benin?
# Answer:  Burkina Faso
# Question:  The Zambesi and which other river define the borders of Matabeleland?
# Answer:  Zambezi and Chobe
# Question:  In which mountains are Camp David?
# Answer:  Catoctin
# Question:  Who sang the title song for the Bond film A View To A Kill?
# Answer:  Duran Duran
# Question:  In which country did General Jaruzelski impose marital law in 1981?
# Answer:  Poland
# Question:  Who won the Oscar for directing It Happened One Night?
# Answer:  Frank
# Question:  Hellenikon international airport is in which country?
# Answer:  Greece
# Question:  Who had a 60s No 1 with Lightnin' Strikes?
# Answer:  Jan & Dean
# Question:  In which year was CNN founded?
# Answer:  1980
# Question:  Which famous brother of Talia Shire does not share her last name?
# Answer:  Nicolas
# Question:  In basketball where do the Celtics come from?
# Answer:  Massachusetts
# Question:  Which Disney film had the theme tune A Whole New World?
# Answer:  Aladdin
# Question:  Florence Ballard was a member of which girl group?
# Answer:  The Supremes
# Question:  Who was born first, Susan Sarandon or Glenn Close?
# Answer:  October
# Question:  Who wrote the novel The Go Between?
# Answer:  L.P. Hartley
# Question:  In which musical do the sweeps sing Chim Chim Cheree?
# Answer:  Mary Poppins
# Question:  Who had a big 60s No 1 with Tossin' and Turnin'?
# Answer:  Brook
# Question:  Sam Phillips was owner of which legendary recording studio?
# Answer:  Sun
# Question:  Which actor played Maxwell Smart?
# Answer:  Don
# Question:  On a computer keyboard which letter on the same line is between C and B?
# Answer:  E
# Question:  In which decade did golfer Gary Player last win the British Open?
# Answer:  1959
# Question:  Sarah FitzGerald has been a 90s world champion in which sport?
# Answer:  Squash
# Question:  Where was the peace treaty signed that brought World War I to an end?
# Answer:  Lausanne
# Question:  Which company was responsible for the oil spill in Alaska in 1989?
# Answer:  Exxon
# Question:  In which decade of the 20th century was Dan Aykroyd born?
# Answer:  1960
# Question:  Which leader did Hitler meet in the Brenner Pass in WWII?
# Answer:  Mussolini
# Question:  Which company first manufactured the electric toothbrush?
# Answer:  Broxo
# Question:  Which actor bought the island of Tetiaroa?
# Answer:  Marlon Brando
# Question:  Between 1952 and 1954 did the number of TV stations in the USA double, triple or quadruple?
# Answer:  Tripled
# Question:  What was Wham!'s first No 1?
# Answer:  Young Guns (Go for It!)
# Question:  Which musical featured the song You'll Never Walk Alone?
# Answer:  Carousel
# Question:  In which year was Bloody Sunday in Londonderry?
# Answer:  1972
# Question:  The first untethered space walk took place from which space craft?
# Answer:  Challenger
# Question:  Richard Nixon was Vice President to which US state?
# Answer:  California
# Question:  Luxor international airport is in which country?
# Answer:  Egypt
# Question:  Which country did Albert Einstein move to as the Nazis rose to power?
# Answer:  U.S.A.
# Question:  In the 90s how many points have been awarded for finishing first in a Grand Prix?
# Answer:  10
# Question:  Which lawyer made Raymond Burr famous?
# Answer:  Perry Mason
# Question:  Which broadcasting company did Edward J Noble found?
# Answer:  American
# Question:  In which decade did the Jackson 5 sign to Motown?
# Answer:  1969
# Question:  How many vice presidents did Franklin D Roosevelt have?
# Answer:  Three
# Question:  In which state is Harrah's Auto Collection situated?
# Answer:  Nevada
# Question:  What was the name of Gene Autry's horse?
# Answer:  Champion
# Question:  Which city has a sports team of Steelers and team of Pirates?
# Answer:  Pittsburgh
# Question:  What did Fort Dearborn, Indian Territory change its name to?
# Answer:  Indian Territory
# Question:  Bill Berry retired through ill health as a drummer in which band?
# Answer:  R.E.M.
# Question:  Leslie Nielsen trained in which of the armed services in WWII?
# Answer:  Royal Canadian Air Force
# Question:  Which musical featured the song I Feel Pretty?
# Answer:  West Side Story
# Question:  Who produced the first Jetliner in 1957?
# Answer:  De Havilland
# Question:  In which country is the deepwater port of Trondheim?
# Answer:  Norway
# Question:  In which state is Camp David?
# Answer:  Maryland
# Question:  What was the Statue of Liberty originally called?
# Answer:  Liberty Enlightening the World
# Question:  Who sang the Bond theme form From Russia With Love?
# Answer:  Matt Monro
# Question:  Which company was responsible for the oil spill in New York harbor in 1990?
# Answer:  None
# Question:  In which country was Arnold Schwarzenegger born?
# Answer:  Austria
# Question:  Who had an 80s No 1 with Don't You Want Me?
# Answer:  Culture Club
# Question:  Which star of Hannah And Her Sisters has a child called Free?
# Answer:  None
# Question:  Who had 70s hits with Have You Seen Her and Oh Girl?
# Answer:  MC Hammer
# Question:  "What was the name of the ""girl with kaleidoscope eyes"" in a Beatles song?"
# Answer:  Lucy
# Question:  Will Rogers airport was built in which US state?
# Answer:  Oklahoma
# Question:  "What couple live next door to Dagwood and Blondie Bumstead in ""Blondie""?"
# Answer:  The Woodleys
# Question:  Who was the Lone Ranger's great grand-nephew?
# Answer:  Dan
# Question:  "Psychologist William Moulton Marston, inventor of the polygraph, or lie detector, also created a famous comic book heroine,. Who was she?"""
# Answer:  Wonder Woman
# Question:  """Last night I dreamt I went to Manderley again,"" was the first line of what Daphne du Maurier novel?"
# Answer:  Rebecca
# Question:  "What is the actual title of Leonardo da Vinci's ""Mona Lisa""?"
# Answer:  La Gioconda
# Question:  In Henry Wadsworth Longfellow's famous poem, Hiawatha, what was the name of Hiawatha's wife?
# Answer:  Minnehaha
# Question:  How many husbands did the Wife of Bath have, as reported in Chaucer's Canterbury Tales?
# Answer:  Three
# Question:  What was the name of the she-ape that rescued the infant Tarzan and raised him to be Lord of the Apes?
# Answer:  Kala
# Question:  What was the title of Mac West's 1959 autobiography?
# Answer:  None
# Question:  What is the native country of Agatha Chrisitie's detective Hercule Poirot?
# Answer:  Belgium
# Question:  What was the hometown of Sgt. Snorkel in Beetle Bailey?
# Answer:  Pork Corners, Kansas
# Question:  In the Robin Hood stories, what was the real name of Little John?
# Answer:  None
# Question:  The Last Of The Really Great Whangdoodles and Mandy are children's books written by what well-known Oscar-winning actress?
# Answer:  Julie
# Question:  By what pseudonym is writer Frederick Dannay Manfred Bennington Lee better known?
# Answer:  Harper
# Question:  What was art-world guru Andy Warhol's name at birth?
# Answer:  Andrew
# Question:  What was the maiden name of Blondie Bumstead, the comic-strip wife of hapless Dagwood Bumstead?
# Answer:  Boopadoop
# Question:  What famous comic strip character was inspired by the 1936 Henry Fonda film Trail of the Lonesome Pine?
# Answer:  Beetle
# Question:  What was the original name of the orphan created in 1924 by cartoonist Harold Gray in the comic strip we know as Little Orphan Annie?
# Answer:  Little Orphan Otto
# Question:  What was the name of Elizabeth Barrett Browning's pet golden cocker spaniel ?
# Answer:  None
# Question:  The title of what poetic drama by Robert Browning was used to name a Kentucky town?
# Answer:  Caliban
# Question:  How much time did Jonah spend in the belly of the whale?
# Answer:  Three
# Question:  How tall was Goliath, the Philistine giant slain by David with a stone hurled from a sling?
# Answer:  Six feet
# Question:  In what language was the New Testament originally written?
# Answer:  Greek
# Question:  Who were the parents of King Solomon?
# Answer:  David
# Bathsheba
# Question:  What is the name of Dr. Seuss's egg-hatching elephant?
# Answer:  Horton
# Question:  To whom did Herman Melville dedicate his novel, Moby Dick?
# Answer:  Nathaniel Hawthorne
# Question:  "Under what assumed name did Oscar Wilde live out the last three years of his life, in ""France?"
# Answer:  Paris
# Question:  What was Scarlett O'Hara's real first name?
# Answer:  Katie
# Question:  "What one word was intentionally left out of the movie version of Mario Puzo's novel, ""The Godfather"". even though this word was the working title of the book?"
# Answer:  Mafia
# Question:  In the comic strips, what was the name of Mandrake the Magician's giant partner?
# Answer:  Lothar
# Question:  What was the name of the pig leader in George Orwell's Animal Farm?
# Answer:  Napoleon
# Question:  Tess Trueheart is the wife of what comic strip character?
# Answer:  Dick Tracy
# Question:  In the Little Orphan Annie comic strip, what was the name of Daddy Warbucks's Giant bodyguard who wore a turban?
# Answer:  Punjab
# Question:  Who was British Prime Minister when World War II broke out?
# Answer:  Neville Chamberlain
# Question:  How was Oflag IVC prison camp better known?
# Answer:  Colditz
# Question:  Who succeeded Theodore Roosevelt as President?
# Answer:  William Howard Taft
# Question:  To whom did the Bee Gees pay tribute in Tapestry Revisited?
# Answer:  Carole King
# Question:  Who was born first, James Caan or Michael Douglas?
# Answer:  Michael
# Question:  In which country is the deepwater ort of Brindisi?
# Answer:  Italy
# Question:  The word anchorman was credited by Sig Michelson about which CBS News Legend?
# Answer:  Paul
# Question:  Who wrote The Picture Of Dorian Gray?
# Answer:  Oscar
# Question:  Who sang the title song for the Bond film You Only Live Twice?
# Answer:  Nancy
# Question:  Who had a big 90s No 1 with This Is How We Do It?
# Answer:  Montell Jordan
# Question:  Which national park, famous for aboriginal rock paintings, is near Darwin?
# Answer:  Kakadu
# Question:  In TV's All In The Family what was Mike and Gloria's son called?
# Answer:  Joey
# Question:  Who sang with Crosby, Stills and Young?
# Answer:  Graham
# Question:  In which John Logie Baird invent television?
# Answer:  Scotland
# Question:  Who sang the title song for the Bond film License To Kill?
# Answer:  Gladys Knight
# Question:  Black or White came from which Michael Jackson album?
# Answer:  Dangerous
# Question:  On a computer keyboard, which letter is between G ad J?
# Answer:  F
# Question:  In which town or city was General Motors founded?
# Answer:  Flint
# Question:  In which country was the Russian Revolutionary Leon Trotsky murdered?
# Answer:  Mexico
# Question:  Which duo had a 60s No 1 with A World Without Love?
# Answer:  Peter and Gordon
# Question:  In which US state was Tennessee Williams born?
# Answer:  Mississippi
# Question:  Who was Israeli Prime Minister from 1969 to 1974?
# Answer:  Golda Meir
# Question:  Bob Gaudio and Nick Massi sang with which group?
# Answer:  Four Lovers
# Question:  In which country was Angelica Huston born?
# Answer:  United States
# Question:  What were the first two names of 'Cannonball' Adderley?
# Answer:  Julian
# Question:  Carrasco international airport is in which country?
# Answer:  Uruguay
# Question:  What was the profession of New Yorker Garry Winogrand?
# Answer:  Street photographer
# Question:  Amelia Earhart was born in which state?
# Answer:  Kansas
# Question:  Who was Theodore Roosevelt's Vice President between 1901 and 1905?
# Answer:  Charles G. Hawes
# Question:  What was Phil Collins' last UK No 1 of the 80s?
# Answer:  "Sussudio"
# Question:  What was Al Pacino's first movie?
# Answer:  Me, Natalie
# Question:  In which year did Alcock and Brown make their Atlantic crossing?
# Answer:  1919
# Question:  Which singer wrote the musical Someone Like You?
# Answer:  Elton
# Question:  With which instrument was Charlie Christian associated?
# Answer:  guitar
# Question:  In which country is the Howrah bridge?
# Answer:  India
# Question:  What are the international registration letters of a vehicle from Brunei?
# Answer:  BRN
# Question:  What was Oliver Hardy's real first name?
# Answer:  Norvell
# Question:  Benito Juarez international airport is in which country?
# Answer:  Mexico
# Question:  How old would Rocky Marciano have been had he lived to the end of the 20th century?
# Answer:  47
# Question:  Who had a 70s No 1 hit with The Night The Lights Went Out In Georgia?
# Answer:  Vicki
# Question:  Which country does the airline Gronlandsfly come from?
# Answer:  Greenland
# Question:  In Greek mythology, who was the goddess of the rainbow?
# Answer:  Irises
# Question:  In ancient Athens, what tree was considered sacred -- with all its fruit belonging to the state, and death the penalty for anyone caught cutting one down?
# Answer:  Olive
# Question:  What legendary fire-breathing female monster had a lion's head, a goat's body and a dragon's tail?
# Answer:  Humbaba
# Question:  According to legend, who fired the arrow that hit Achilles in the heel, his only vulnerable spot?
# Answer:  Paris
# Question:  In Greek mythology, who was the queen of the underworld and wife of Hades?
# Answer:  Persephone
# Question:  "According to hippy guru Dr. Timothy Leary, what did you do before you ""drop out?"""
# Answer:  tuned in
# Question:  What is Nelson Mandela's middle name?
# Answer:  Rolihlahla
# Question:  How old would James Dean have been had he lived to the end of the 20th century?
# Answer:  88
# Question:  What was Christopher Reeve's first movie?
# Answer:  Street Smart
# Question:  The Porcaro Brothers featured in which group?
# Answer:  Toto
# Question:  Which city was called Leninakan until 1990?
# Answer:  Leninakan
# Question:  What is Iggy Pop's real name?
# Answer:  James
# Question:  What did Franz Kafka do for a day job?
# Answer:  Insurance worker
# Question:  Dorval International airport is in which country?
# Answer:  Canada
# Question:  Who wrote the song Momma Told Me Not To Come?
# Answer:  Randy
# Question:  Who founded the Organization of Afro American Unity?
# Answer:  Malcolm X
# Question:  Which NASA space probe was launched to Venus in 1989?
# Answer:  None
# Question:  Who directed Good Morning Vietnam?
# Answer:  Oliver Stone
# Question:  What was Bette Davis's real first name?
# Answer:  Betty
# Question:  In which sport did Hollywood star Sonja Henie win Olympic Gold?
# Answer:  Figure Skating
# Question:  Who won Super Bowl XXV?
# Answer:  Giants
# Question:  Robert Mueller Municipal Airport is in which US state?
# Answer:  Texas
# Question:  In what year were women first admitted to Harvard?
# Answer:  1859
# Question:  Who had 70s No 1 hit with Show and Tell?
# Answer:  Al
# Question:  Balice international airport is in which country?
# Answer:  Poland
# Question:  Panama proclaimed independence in 1903 from which country?
# Answer:  Colombia
# Question:  How old was Ronald Reagan when he became US President?
# Answer:  41
# Question:  Which Iowa-born artist painted American Gothic and Spring Turning?
# Answer:  Grant
# Question:  Which country does the airline Garuda come from?
# Answer:  Indonesia
# Question:  Sarah Vaughan first joined which band as singer?
# Answer:  Count Basie
# Question:  Which pioneering aviator had a plane called Percival Gull?
# Answer:  Edgar Percival
# Question:  Henri Becquerel shared a Nobel prize for his work in discovering what?
# Answer:  Radioactivity
# Question:  Who was the first white music star to record on Atlantic, through its sister label Atco?
# Answer:  Jay Holliday
# Question:  Who took the assumed name Sebastian Melmoth when living in Paris?
# Answer:  Napoleon
# Question:  Who founded the off-Broadway theater where Hair had its premier?
# Answer:  Joseph
# Question:  Established in 1919, which is the world's oldest surviving airline?
# Answer:  Avianca
# Question:  "Which US First Lady said, ""No one can make you feel interior unless you consent?"""
# Answer:  Eleanor Roosevelt
# Question:  Who won super bowl X?
# Answer:  Steeler
# Question:  Who brought to an end Jahangir Khan's long unbeaten run of success in squash in the 80s?
# Answer:  Ross Norman
# Question:  Jomo Kenyatta was born into which tribe?
# Answer:  Kikuyu
# Question:  Bryan Abrams, Sam Walters, Mark Calderon and Kevin Thornton formed which group?
# Answer:  Color Me Badd
# Question:  When was the Scrabble World championship first held?
# Answer:  1991
# Question:  Arlanda international airport is in which country?
# Answer:  Sweden
# Question:  What year was the centenary of Arkansas joining the Union?
# Answer:  1856
# Question:  Who duetted with Barbra Streisand on Till I Loved You in 1988?
# Answer:  Don Johnson
# Question:  What was first published on 21st December 1913 in the New York World?
# Answer:  Nothing
# Question:  What finally knocked One Sweet Day off the No 1 position in the charts in the 90s?
# Answer:  Celine
# Question:  Which actor paid $93,500 for the baseball which rolled between Bill Buckner's legs in game six of the 1986 World Series?
# Answer:  Charlie
# Question:  Who was Theodore Roosevelt's Vice President between 1905 and 1909?
# Answer:  Charles G. Dawes
# Question:  Which nation was the first to ratify the United Nations charter in 1945?
# Answer:  China
# Question:  What is the Alaskan terminus of the Alaskan Highway?
# Answer:  Delta Junction
# Question:  What was Buster Keaton's actual first name?
# Answer:  Joseph
# Question:  From 1903 to 1958, every Pope--bar one--took which name?
# Answer:  Pius
# Question:  What was the title of Kitty Kelley's book about Elizabeth Taylor?
# Answer:  Elizabeth Taylor: The Last Star
# Question:  What are the international registration letters for a vehicle form Jordan?
# Answer:  XX
# Question:  In which country was Julie Christie born?
# Answer:  India
# Question:  Which artist created the Katzenjammer Kids?
# Answer:  Rudolph Dirks
# Question:  Who had a 60s No 1 hit with Johnny Angel?
# Answer:  Shelley Fabares
# Question:  Which country does the airline VIASA come from?
# Answer:  Venezuela
# Question:  Who directed Back To The Future?
# Answer:  Robert Zemeckis
# Question:  Where was Che Guevara killed?
# Answer:  La Higuera
# Question:  Daryl Dragon used which name when he formed a 70s duo?
# Answer:  Captain
# Question:  Which has the highest population, Rode island or South Dakota?
# Answer:  South Dakota
# Question:  What was Oliver Reed's real first name?
# Answer:  Oliver
# Question:  Who wrote the song Harper Valley PTA?
# Answer:  Tom T. Hall
# Question:  Who choreographed the first performance of Copland's Rodeo?
# Answer:  Agnes de Mille
# Question:  Who wrote Riders of the Purple Sage?
# Answer:  Zane Grey
# Question:  Who directed The Big Sleep and Gentlemen Prefer Blondes?
# Answer:  Howard
# Question:  In which year was the talkie The Jazz Singer released?
# Answer:  1927
# Question:  Alborg Roedslet international airport is in which country?
# Answer:  Denmark
# Question:  What was Elton John's first US No 1 hit?
# Answer:  Crocodile Rock
# Question:  In which decade was the Oral Roberts University founded at Tulsa?
# Answer:  1960s
# Question:  On which label did the Beach boys record most of their 60s hits?
# Answer:  Capitol
# Question:  Whose musical works included Composition For Orchestra and Philomel?
# Answer:  Milton Babbitt
# Question:  What was the first state to join the Union in the 20th century?
# Answer:  Alaska
# Question:  Where were the 2004 Summer Olympic Games held?
# Answer:  Athens
# Question:  When she died how old was Karen Carpenter?
# Answer:  33
# Question:  In which state was Charles Schulz born?
# Answer:  Minnesota
# Question:  "Who wrote, ""What is this life if full of care, We have no time to stand and stare?"""
# Answer:  W.H. Davies
# Question:  In what year was Oliver Stone born?
# Answer:  1946
# Question:  What disability did singer Al Hibbler have?
# Answer:  None
# Question:  Which country does the airline Ansett come from?
# Answer:  Australia
# Question:  Where is New York's Empire State College located?
# Answer:  Morningside Heights
# Question:  Where was Pablo Casals buried before he was finally laid to rest in Spain?
# Answer:  San Juan
# Question:  Santander international airport is in which country?
# Answer:  Spain
# Question:  In which year was Nigel Mansell Indy Car Champion?
# Answer:  1993
# Question:  Thomas Marshal was Vice President to which US President?
# Answer:  Woodrow Wilson
# Question:  Which year was the first after 1927 that the USA lost the Ryder Cup on home soil?
# Answer:  1987
# Question:  Ellen Church is recognized as being the first female what?
# Answer:  flight attendant
# Question:  Which country does the airline Avensa come from?
# Answer:  Venezuela
# Question:  What was the USA's biggest attack of the Vietnam War when it took place in February 1967?
# Answer:  Junction City
# Question:  What was Michael Keaton's first movie?
# Answer:  Night Shift
# Question:  What is Uma Thurman's middle name?
# Answer:  Karuna
# Question:  What was the name of NASA's manned space project whose astronauts were chosen in 1959?
# Answer:  Project Mercury
# Question:  In which country was Anjelica Huston born?
# Answer:  United States
# Question:  Who preceded Hosni Mubarak as President of Egypt?
# Answer:  Anwar Sadat
# Question:  What instrument is associated with Illinois-born John Lewis?
# Answer:  Piano
# Question:  What type of aid was developed my Miller Hutchinson in the early years of the 20th century?
# Answer:  Electric
# Question:  John Singer Sargent worked in which branch of the arts?
# Answer:  Painting
# Question:  Cuscatlan international airport is in which country?
# Answer:  None
# Question:  What was Gene Kelly's middle name?
# Answer:  Curran
# Question:  What was the profession of William Eugene Smith?
# Answer:  Photojournalist
# Question:  Which country does the airline Pluna come form?
# Answer:  Uruguay
# Question:  Who directed A Passage To India?
# Answer:  David Lean
# Question:  What is Gregory Peck's real first name?
# Answer:  Eldred
# Question:  Golfer Bobby Jones was born in which state?
# Answer:  None
# Question:  What was the world's first atomic-powered ship called?
# Answer:  USNS Savannah
# Question:  Which architect designed the Seagram Building, New York City?
# Answer:  Ludwig Mies van der Rohe
# Question:  In what year was the first performance of Copland's ballet Rodeo?
# Answer:  1942
# Question:  Ferihegy international airport is in which country?
# Answer:  Hungary
# Question:  Who was the defending champion when Virginia Wade won the Wimbledon singles?
# Answer:  Chris Evert
# Question:  How many 'victories' did The Red Baron claim in aerial dogfights?
# Answer:  80
# Question:  Who first coined the term paradigm for all the factors that influence the scientist's research?
# Answer:  Thomas
# Question:  In which country was Sam Neill born?
# Answer:  Northern Ireland
# Question:  What was Dorothy Parker's maiden name?
# Answer:  Rothschild
# Question:  In which month in 1997 was The Notorious B.I.G. gunned down?
# Answer:  March
# Question:  What was the official occupation of Sir Anthony Blunt who was unmasked as a Soviet spy in 1979?
# Answer:  Professor of the History of Art
# Question:  Which famous name was accused f the abduction of Stompie Seipei?
# Answer:  Winnie
# Question:  What was the highest rank Charles Lindbergh attained?
# Answer:  Captain
# Question:  Who was the second person to make a solo transatlantic flight?
# Answer:  Wiley Post
# Question:  Who was the third wife of the leader of China's Long March?
# Answer:  He
# Question:  In 1985 Terry Waite returned to Beirut after securing the release of four British hostages where?
# Answer:  Lebanon
# Question:  UN Secretary Dag Hammarskjold was killed over which country?
# Answer:  Uganda
# Question:  What was the autobiography of the first president of non-Apartheid South Africa called?
# Answer:  Unpublished
# Question:  Which terrorist group murdered Italian Prime Minister Aldo Moro?
# Answer:  Red Brigades
# Question:  General Boris Gromov was the last Soviet soldier to leave where in 1989?
# Answer:  Afghanistan
# Question:  In what year did Saddam Hussein become President of Iraq?
# Answer:  1979
# Question:  Who became leader of the Bosnian Serbs in 1992?
# Answer:  Radovan Karadžić
# Question:  Who was deputy commander of the 1983 US invasion of Grenada?
# Answer:  Vice Admiral Joseph Metcalf, III
# Question:  What was Mother Teresa's real first name?
# Answer:  Anjezë
# Question:  Who was America's first world chess champion?
# Answer:  None
# Question:  Which Swiss-born Californian first used an amplifier with a guitar?
# Answer:  None
# Question:  Who was chairman of the Watergate hearings?
# Answer:  Sam Ervin
# Question:  Who was credited with popularizing the term rock 'n' roll?
# Answer:  Alan
# Question:  What were Gary Gilmore's final words before his execution in 1977?
# Answer:  Dominus vobiscum
# Question:  In which country was Ivana Trump born and brought up?
# Answer:  Czechoslovakia
# Question:  Who wrote the stage musical Cabaret?
# Answer:  John Kander
# Question:  Flamenco dancer Joaquin Cortes hit the headlines in 1996 over his relationship with which supermodel?
# Answer:  Naomi
# Question:  How old was George Gershwin when he died?
# Answer:  38
# Question:  Which golfer became only the fifth in history to win both the British and US Open championships in the same year, in 1982?
# Answer:  Jack Nicklaus
# Question:  How many times did tennis legend Jimmy Connors win the US Open in the 1970s?
# Answer:  Three
# Question:  Which pop star did model Iman marry in 1992?
# Answer:  David
# Question:  Which actress links Dorothy in The Golden Girls and Maude Findlay in Maude?
# Answer:  Rue
# Question:  What was the name of Jed's nephew in The Beverly Hillbillies?
# Answer:  Jethro
# Question:  What was Green Acres called on radio?
# Answer:  Granby's Green Acres
# Question:  Which 90s sitcom character was said to be a symbol of failing values which caused LA riots, according to Dan Quayle?
# Answer:  Murphy Brown
# Question:  According to the series when was the Cheers bar founded?
# Answer:  1889
# Question:  Which sitcom with Vickie Lawrence was a spin-off from the Carol Burnett Show?
# Answer:  Mama's Family
# Question:  Who was creator and executive producer of Magnum PI?
# Answer:  Glen A. Larson
# Question:  What was the name of the vet in Daktari?
# Answer:  Dr. Marsh Tracy
# Question:  Who bought CBS in 1929 and remained on the board until 1983?
# Answer:  William S. Paley
# Question:  Which executive producer of Dream On is well known for films such as Trading Places?
# Answer:  John Landis
# Question:  "To which interviewer did Richard Nixon say, ""I never cry except in public?"
# Answer:  Conrad Black
# Question:  Who did Dick Van Dyke play in The Dick Van Dyke Show?
# Answer:  Rob
# Question:  Which English actress and star of Primary Colors appeared as a guest in Cheers?
# Answer:  Emma Thompson
# Question:  What was the first sitcom to reach No 1 in the Nielsen ratings?
# Answer:  I Love Lucy
# Question:  Who in the singing Jackson family appeared in Different Strokes?
# Answer:  Janet
# Question:  What was the first spin-off from The Beverly Hillbillies called?
# Answer:  Petticoat Junction
# Question:  Which series was a spin off from the Golden Girls spin-off, Empty Nest?
# Answer:  Nurses
# Question:  Which character did Burt Reynolds play in Evening Shade?
# Answer:  Wood Newton
# Question:  Which comedian starred in the ABC sitcom Chicken Soup?
# Answer:  Jackie Mason
# Question:  Who did Debbie play in The Debbie Reynolds Show?
# Answer:  Debbie
# Question:  Dorothy, Rose, Sophia and who else formed the Golden Girls?
# Answer:  Blanche
# Question:  Who first funded Sesame Street?
# Answer:  Carnegie
# Question:  In Family Affair what was the butler called?
# Answer:  Mr. French
# Question:  In the Addams Family, what is Gomez's octopus called?
# Answer:  Thing
# Question:  Which character did Betty White play in The Betty White Show?
# Answer:  Joyce Whitman
# Question:  During the series Roseanne changed her name to Arnold from what?
# Answer:  After marriage
# Question:  Which hotel sitcom was based on the British series Fawlty Towers?
# Answer:  Chateau Snavely
# Question:  In which year did Tanganyika and Zanzibar merge to form Tanzania?
# Answer:  1964
# Question:  In which decade did motor car pioneer Henry Ford die?
# Answer:  1940s
# Question:  Ed Gagliardi, Al Greenwood and Dennis Elliot have all been in which group?
# Answer:  Foreigner
# Question:  "Which song starts, ""On a dark desert highway?"""
# Answer:  Hotel
# Question:  What was Rambo's first name?
# Answer:  Rambo
# Question:  When did field hockey become an Olympic event for men?
# Answer:  1920
# Question:  Bill Cosby had a professional trial in which sport?
# Answer:  Baseball
# Question:  What was the first film Alfred Hitchcock made in Hollywood?
# Answer:  Suspicion
# Question:  Bujumbura international airport is in which country?
# Answer:  Burundi
# Question:  The painting The Scream was stolen form which city in 1994?
# Answer:  Oslo
# Question:  What was Paul Newman's first movie?
# Answer:  The Silver Chalice
# Question:  Which University of Wisconsin has the highest enrolment figure?
# Answer:  29,302
# Question:  What is Diane Keaton's real name?
# Answer:  Diane
# Question:  Which word used to be in the name of The San Francisco Ballet?
# Answer:  Opera
# Question:  What nationality were Mother Teresa's parents?
# Answer:  Albanian
# Question:  Who had a 60s No 1 hit with I'm Telling You Now?
# Answer:  Al Wilson
# Question:  Which philosopher wrote Eros and Civilization and One Dimensional Man?
# Answer:  Herbert Marcuse
# Question:  What are the international registration letters of a vehicle from Sri Lanka?
# Answer:  SLZ
# Question:  Who directed the movie East of Eden?
# Answer:  Elia Kazan
# Question:  In which year did Count Basie die?
# Answer:  1984
# Question:  Which bridge is the subject of Hart Crane's The bridge?
# Answer:  Brooklyn
# Question:  Who is credited with inventing the Tarzan yodel?
# Answer:  Carol Burnett
# Question:  In which state do most Cree Indians live in the USA?
# Answer:  Montana
# Question:  Bob Dole trained for which profession although he didn't qualify?
# Answer:  Medicine
# Question:  Out of 11 series of prime time seasons how many times did Happy days make the Nielsen Top Twenty?
# Answer:  Eight
# Question:  Who wrote the novel Watership Down?
# Answer:  Richard
# Question:  Who was the Prime Minister of Australia from 1983 - 1991?
# Answer:  Bob Hawke
# Question:  On which river was the Kariba Dam built?
# Answer:  Zambezi
# Question:  Detroit born Diana Earle became famous under which name?
# Answer:  Supremes
# Question:  Who wrote God Bless America?
# Answer:  Irving Berlin
# Question:  What was Sean Penn's first movie?
# Answer:  Taps
# Question:  Who had and 80s NO 1 with The Tide is High?
# Answer:  Blondie
# Question:  In which Bond film did Britt Ekland appear?
# Answer:  Live and Let Die
# Question:  What is Mick Jagger's middle name?
# Answer:  Philip
# Question:  Boxer Jack Dempsey hailed from which state?
# Answer:  Colorado
# Question:  Which British liner was sunk by a German submarine in 1915?
# Answer:  Audacious
# Question:  Which role as 'the other woman' won Glenn Close her first Oscar nomination?
# Answer:  Fatal Attraction
# Question:  Who wrote the novel The Godfather?
# Answer:  Mario
# Question:  Jack Sharkey was a world champion in which sport?
# Answer:  boxing
# Question:  What was Marilyn Monroe's last film?
# Answer:  The Misfits
# Question:  What was Bix Beiderbecke's principal musical instrument?
# Answer:  Cornet
# Question:  US-born Adulyadej Bhumibol became king of which Asian country?
# Answer:  Thailand
# Question:  In 1971 Leonard Bernstein wrote a Mass in whose memory?
# Answer:  John
# Question:  Who had a big 50s No 1 with A Big Hunk O' Love?
# Answer:  Elvis Presley
# Question:  Whose first hit was Maybellene in 1955?
# Answer:  Chuck
# Question:  What goes after Love Will Never Do on Janet Jackson's 1990 hit?
# Answer:  Single
# Question:  Which Gloria co-founded Ms magazine?
# Answer:  Steinem
# Question:  A Fistfull of Dollars was filmed on location in which country?
# Answer:  Spain
# Question:  Which country lies immediately to the south of Estonia?
# Answer:  Latvia
# Question:  In which year was the University of Alaska Anchorage founded?
# Answer:  1954
# Question:  What star sign is shared by peter Gabriel and Stevie Wonder?
# Answer:  Aquarius
# Question:  What was John Huston's last movie?
# Answer:  The Dead
# Question:  Who won Super Bowl III?
# Answer:  New York Jets
# Question:  What is Marie Osmond's real first name?
# Answer:  Olivia
# Question:  Calabar international airport is in which country?
# Answer:  Nigeria
# Question:  Which country did Thor Heyerdahl's Kon-Tiki set sail from on its journey to Eastern Polynesia?
# Answer:  South America
# Question:  Donna Gaines is better known by which name?
# Answer:  Donna Summer
# Question:  Which element is named after Pierre and Marie Curie?
# Answer:  Curiu
# Question:  By the end of the 20th century how many times had Meryl Streep been nominated for an Oscar?
# Answer:  12
# Question:  Both Richard and Karen Carpenter came fro which state?
# Answer:  California
# Question:  What was Mr. Magoo's first name?
# Answer:  None
# Question:  Which rock star featured in Marvel's 50th issue of Marvel Premiere in 1979?
# Answer:  Alice
# Question:  Who was runner-up when Jody Scheckter won motor racing's Formula One Championship?
# Answer:  Niki Lauda
# Question:  In what year of the 1990s was baseball's World Series canceled?
# Answer:  1994
# Question:  Who first flew in Friendship 7?
# Answer:  John Glenn
# Question:  Who had a 50s No 1 with Stagger Lee?
# Answer:  Lloyd Price
# Question:  Who wrote the novel Gentlemen Prefer Blondes?
# Answer:  Anita Loos
# Question:  Which country does the airline Gulf Air come from?
# Answer:  Bahrain
# Question:  What is Alistair Cooke's real first name?
# Answer:  Alfred
# Question:  How is seriously rich Percy Miller better known?
# Answer:  Master P
# Question:  How old was Laurel and Hardy producer Hal Roach when he died in 1992?
# Answer:  Not available
# Question:  Who was West German Chancellor from 1969 to 1974? Willy Brandt.
# Answer:  Willy Brandt
# Question:  What sort of Menace was the 1999 Star Wars movie?
# Answer:  Phantom
# Question:  What was the name of Drew Barrymore's character in E.T.?
# Answer:  Gertie
# Question:  Which ER star played opposite Jenny Seagrove in Don' Go Breaking My Heart?
# Answer:  Anthony Edwards
# Question:  Who played Rick Deckard in Blade Runner?
# Answer:  Harrison
# Question:  What was the fourth Alien film called?
# Answer:  None
# Question:  What number Star Trek movie was called The Wrath of Khan?
# Answer:  2
# Question:  Which King did Leonardo Di Caprio play in The Man in the Iron Mask?
# Answer:  Louis XIV
# Question:  Which role did Rupert Everett play in The Madness of King George?
# Answer:  George, the Prince of Wales
# Question:  What was Stanley Kubrick's final movie?
# Answer:  Eyes Wide Shut
# Question:  Who tries to save the world from virtual reality in The Matrix?
# Answer:  Neo
# Question:  Which decade does Michael J Fox go back to in Back to the Future?
# Answer:  1950
# Question:  In which 90s movie did Al Pacino play retired Colonel Frank Slade?
# Answer:  Scent of a Woman
# Question:  What is the name of Kate Winslet's character in Titanic?
# Answer:  Rose
# Question:  Which spin-off from a 60s sitcom was a 1999 movie with Jeff Daniels and Christopher Lloyd?
# Answer:  My Favorite Martian
# Question:  Who played the young Obi-Wan Kenobi in the Star Wars prequel?
# Answer:  Jake Lloyd
